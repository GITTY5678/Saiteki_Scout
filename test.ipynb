# %%
from saiteki_scout import Time_Complexity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from saiteki_scout import Time_Complexity
#
# ModuleNotFoundError: No module named 'saiteki_scout'

# %%
import sys
sys.path
# Out:
# ['/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/home/harihara-suthan-s/Saiteki_Scout/venv/lib/python3.12/site-packages']

# %%
import sys

sys.path.append("src")

# %%
from saiteki_scout import Time_Complexity
